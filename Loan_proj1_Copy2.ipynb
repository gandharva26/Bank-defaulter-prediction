# %%
import pandas as pd
import numpy as np

# %%
loan=pd.read_excel("Document from Gandharva.xlsx")

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade            ...              \
# 0    0.1065       162.87     B        B2            ...
# 1    0.1527        59.83     C        C4            ...
# 2    0.1596        84.33     C        C5            ...
# 3    0.1349       339.31     C        C1            ...
# 4    0.1269        67.79     B        B5            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                NaN                NaN            NaN               NaN
# ...

# %%
loan["application_type"].value_counts()
# Out:
# INDIVIDUAL    39717
# Name: application_type, dtype: int64

# %%
loan["pymnt_plan"].value_counts()
loan["term"].value_counts()
loan["pub_rec_bankruptcies"].value_counts()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: mort_acc, dtype: float64

# %%
loan.ndim
# Out:
# 2

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
LevelEncod=LabelEncoder()
loan["grade"]=LevelEncod.fit_transform(loan["grade"])
loan["term"]=LevelEncod.fit_transform(loan["term"])
loan["pub_rec_bankruptcies"]=LevelEncod.fit_transform(loan["pub_rec_bankruptcies"])
loan.head()
loan.loc[loan.loan_status=='Fully Paid','loan_status']=1
loan.loc[loan.loan_status=='Charged Off','loan_status']=0
loan.loc[loan.loan_status=='Current','loan_status']=1
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0     0
# 1  1077430    1314167       2500         2500           2500.0     1
# 2  1077175    1313524       2400         2400           2400.0     0
# 3  1076863    1277178      10000        10000          10000.0     0
# 4  1075358    1311748       3000         3000           3000.0     1
#
#    int_rate  installment  grade sub_grade            ...              \
# 0    0.1065       162.87      1        B2            ...
# 1    0.1527        59.83      2        C4            ...
# 2    0.1596        84.33      2        C5            ...
# 3    0.1349       339.31      2        C1            ...
# 4    0.1269        67.79      1        B5            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                NaN                NaN            NaN               NaN
# ...

# %%
loan['pub_rec_bankruptcies'].value_counts()

# %%
x=loan.drop(loan[loan.loan_status=='Charged Off'].index)//x data frame for non defaulters

# %%
x["loan_status"]
# Out:
# 0        Fully Paid
# 2        Fully Paid
# 3        Fully Paid
# 4           Current
# 5        Fully Paid
# 6        Fully Paid
# 7        Fully Paid
# 10       Fully Paid
# 11       Fully Paid
# 13       Fully Paid
# 15       Fully Paid
# 16       Fully Paid
# 17       Fully Paid
# 18       Fully Paid
# 19       Fully Paid
# 20       Fully Paid
# 22       Fully Paid
# 23       Fully Paid
# 25       Fully Paid
# 28       Fully Paid
# 29       Fully Paid
# 30       Fully Paid
# 31       Fully Paid
# 32          Current
# 33       Fully Paid
# 34       Fully Paid
# 35       Fully Paid
# 36       Fully Paid
# 37       Fully Paid
# 38       Fully Paid
#             ...
# 39686    Fully Paid
# 39687    Fully Paid
# 39689    Fully Paid
# 39690    Fully Paid
# 39691    Fully Paid
# 39692    Fully Paid
# 39693    Fully Paid
# 39694    Fully Paid
# 39695    Fully Paid
# 39696    Fully Paid
# 39697    Fully Paid
# 39698    Fully Paid
# 39699    Fully Paid
# 39700    Fully Paid
# ...

# %%
df3=loan[["installment","int_rate","loan_amnt","max_bal_bc","revol_bal","loan_status","grade","term","pub_rec_bankruptcies"]]

df3.hea

# %%
df3.head()
y=df3["loan_status"]

# %%
df3.drop('loan_status',axis=1,inplace=True)
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.drop('max_bal_bc',axis=1,inplace=True)
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x=df3
x.head()
# Out:
#    installment  int_rate  loan_amnt  revol_bal  grade  term  \
# 0       162.87    0.1065       5000      13648      1     0
# 1        59.83    0.1527       2500       1687      2     1
# 2        84.33    0.1596       2400       2956      2     0
# 3       339.31    0.1349      10000       5598      2     0
# 4        67.79    0.1269       3000      27783      1     1
#
#    pub_rec_bankruptcies
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
score = logmodel.score(x_test, y_test)
print(score)
# Out:
# 0.8576703591809332

# %%
import seaborn as sns

# %%
sns.heatmap(loan.corr()) #finding highest correlated features for pruning

# %%
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.FacetGrid(loan[:1000], hue="loan_status") \
   .map(plt.scatter, "loan_amnt", "int_rate") \
   .add_legend()
plt.show()   #are the data points separable or are there any significant patterns between interest rate and loan amnt separating on loanstatus

# %%
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.FacetGrid(loan[:1000], hue="loan_status") \
   .map(plt.scatter, "installment", "revol_bal") \
   .add_legend()
plt.show()#is there any relation between revolbal and installment

# %%
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.FacetGrid(loan[:4000], hue="loan_status") \
   .map(plt.scatter, "grade", "pub_rec_bankruptcies") \
   .add_legend()
plt.show()   #relation between grade and bankruptcies , how it impacts loan status

# %%
sns.FacetGrid(loan[:4000], hue="loan_status") \
   .map(sns.distplot, "loan_amnt") \
   .add_legend()
plt.show()  # which parameter is essential for classification of loan status
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(loan[:4000], hue="loan_status") \
   .map(sns.distplot, "grade") \
   .add_legend()
plt.show()  # which parameter is essential for classification of loan status
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(loan[:4000], hue="loan_status") \
   .map(sns.distplot, "int_rate") \
   .add_legend()
plt.show()  # which parameter is essential for classification of loan status
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(loan[:4000], hue="loan_status") \
   .map(sns.distplot, "revol_bal") \
   .add_legend()
plt.show()  # which parameter is essential for classification of loan status
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0     0
# 1  1077430    1314167       2500         2500           2500.0     1
# 2  1077175    1313524       2400         2400           2400.0     0
# 3  1076863    1277178      10000        10000          10000.0     0
# 4  1075358    1311748       3000         3000           3000.0     1
#
#    int_rate  installment  grade sub_grade            ...              \
# 0    0.1065       162.87      1        B2            ...
# 1    0.1527        59.83      2        C4            ...
# 2    0.1596        84.33      2        C5            ...
# 3    0.1349       339.31      2        C1            ...
# 4    0.1269        67.79      1        B5            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                NaN                NaN            NaN               NaN
# ...

# %%
df4=loan[["installment","int_rate","loan_amnt","max_bal_bc","revol_bal","loan_status","grade","term","pub_rec_bankruptcies"]]

# %%
import matplotlib.pyplot as plt
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df4.head(), hue="loan_status")

plt.show()
# Out:
# C:\Users\Gandharva\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\Gandharva\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d59ca14cd66b> in <module>()
#       2 plt.close()
#       3 sns.set_style("whitegrid")
# ----> 4 sns.pairplot(df4.head(), hue="loan_status")
#       5 #sns.pairplot(iris, hue="species", size=3, diag_kind ='none')
#       6 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 9 columns):
# installment             39717 non-null float64
# int_rate                39717 non-null float64
# loan_amnt               39717 non-null int64
# max_bal_bc              0 non-null float64
# revol_bal               39717 non-null int64
# loan_status             39717 non-null int64
# grade                   39717 non-null int64
# term                    39717 non-null int64
# pub_rec_bankruptcies    39717 non-null int64
# dtypes: float64(3), int64(6)
# memory usage: 2.7 MB

# %%
#Box-plot can be visualized as a PDF on the side-ways.
# the box lines are 25th, 50th, and 75th percentile

sns.boxplot(x='loan_amnt',y='int_rate', data=loan)
plt.show()
